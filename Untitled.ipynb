# %%
# !pip install tensorflow==2.8.0 opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.8.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (2.8.0)
# Requirement already satisfied: opencv-python in c:\users\stanslaus\final_project\final_pro\lib\site-packages (4.5.5.64)
# Requirement already satisfied: mediapipe in c:\users\stanslaus\final_project\final_pro\lib\site-packages (0.8.9.1)
# Requirement already satisfied: sklearn in c:\users\stanslaus\final_project\final_pro\lib\site-packages (0.0)
# Requirement already satisfied: matplotlib in c:\users\stanslaus\final_project\final_pro\lib\site-packages (3.5.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (4.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (3.6.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (2.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: numpy>=1.20 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.22.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: gast>=0.2.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (0.5.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (0.25.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.14.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.44.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (14.0.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorflow==2.8.0) (3.20.1)
# Requirement already satisfied: opencv-contrib-python in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from mediapipe) (4.5.5.64)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: scikit-learn in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from matplotlib) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from matplotlib) (9.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.6.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.27.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from scikit-learn->sklearn) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.0.12)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\stanslaus\final_project\final_pro\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the 'C:\Users\STANSLAUS\Final_project\final_pro\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities


def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results


def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections


#if the arry is blank we fill if with zeros (np.zeros()) Bcz it will give error
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])


#CREATING FOLDERS
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 
# Actions that we try to detect
actions = np.array(['baba', 'mimi', 'mjomba', 'rafiki'])
# Thirty videos worth of data
no_sequences = 30
# Videos are going to be 30 frames in length
sequence_length = 30
# Folder start
start_folder = 30


#loop to create the folders of the videos
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

    
cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
         # Draw landmarks
        draw_landmarks(image, results)
                
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
cap.release()
cv2.destroyAllWindows()

# %%
draw_landmarks(frame, results)

# %%
# it shows the last frame in BGR color
#plt.imshow(frame) 

#it show the last frame with RGB color
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
#2. COLLECTING DATA
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities


def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results


def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections


    
    
def draw_styled_landmarks(image, results):
    # Draw face connections
   # mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
    #mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
    #mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
    #) 

    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
    mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
    mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
    ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
    mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
    mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
    ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
    mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
    mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
    ) 
#if the arry is blank we fill if with zeros (np.zeros()) Bcz it will give error
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])


#CREATING FOLDERS
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 
# Actions that we try to detect
#actions = np.array(['baba', 'mimi', 'mjomba', 'rafiki'])
actions = np.array(['mimi'])
# Thirty videos worth of data
no_sequences = 30
# Videos are going to be 30 frames in length
sequence_length = 30
# Folder start
start_folder = 30


#loop to create the folders of the videos
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

    
cap = cv2.VideoCapture(1)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

label_map = {label:num for num, label in enumerate(actions)}

sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
        
x = np.array(sequences)
y = to_categorical(labels).astype(int)

#spliting our data into TRAIN and TESTING
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.05)


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
#model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])


#not a must------------------------
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
yhat = model.predict(x_test)
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
model.fit(x_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 2/1000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 3/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 4/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 5/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 6/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 7/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 10/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 11/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 12/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 13/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 14/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 15/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 16/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 17/1000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 18/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 19/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 20/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 21/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 22/1000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 23/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 24/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 25/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 26/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 27/1000
# 1/1 [==============================] - 0s 214ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 28/1000
# 1/1 [==============================] - 0s 217ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 29/1000
# 1/1 [==============================] - 0s 137ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 30/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 31/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 32/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 33/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 34/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 35/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 36/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 37/1000
# 1/1 [==============================] - 0s 210ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 38/1000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 39/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 40/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 41/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 42/1000
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 43/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 44/1000
# 1/1 [==============================] - 0s 210ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 45/1000
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 46/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 47/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 48/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 49/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 50/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 51/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 52/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 53/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 54/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 55/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 56/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 57/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 58/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 59/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 60/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 61/1000
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 62/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 63/1000
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 64/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 65/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 66/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 67/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 68/1000
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 69/1000
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 70/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 71/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 72/1000
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 73/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 74/1000
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 75/1000
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 76/1000
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 77/1000
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 78/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 79/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 80/1000
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 81/1000
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch
1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 968/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 969/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 970/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 971/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 972/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 973/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 974/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 975/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 976/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 977/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 978/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 979/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 980/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 981/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 982/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 983/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 984/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 985/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 986/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 987/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 988/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 989/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 990/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 991/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 992/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 993/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 994/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 995/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 996/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 997/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 998/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 999/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1000/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.save('action.h5')

# %%
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 cap.release()
#       2 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined

# %%
res[np.argmax(res)]

# %%
import tkinter as tk
from tkinter import filedialog, Text
import os

root = tk.Tk()

canvas = tk.Canvas(root, height=700, width=1000, bg="#293D42")
canvas.pack()

frame = tk.Frame(root, bg="white")
frame.place(relheight=0.8, relwidth=0.8, relx=0.1, rely=0.1, command=runapp)

openprog = tk.Button(root, text="OPEN", padx=10, pady=5, fg="white", bg="#263D42")
openprog.pack()


root.mainloop()

# %%
import tkinter as tk

def signln():


    # ONE##########################################

    #!pip install tensorflow==2.8.0 tensorflow-gpu==2.8.0 opencv-python mediapipe sklearn matplotlib

    import cv2
    import numpy as np
    import os
    from matplotlib import pyplot as plt
    import time
    import mediapipe as mp


    #2 #######################################################

    mp_holistic = mp.solutions.holistic # Holistic model
    mp_drawing = mp.solutions.drawing_utils # Drawing utilities

    def mediapipe_detection(image, model):
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
        image.flags.writeable = False                  # Image is no longer writeable
        results = model.process(image)                 # Make prediction
        image.flags.writeable = True                   # Image is now writeable 
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
        return image, results

    def draw_styled_landmarks(image, results):
        # Draw face connections
        #mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
         #                        mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
          #                       mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
           #                      ) 

        # Draw pose connections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 ) 
        # Draw left hand connections
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 ) 
        # Draw right hand connections  
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 ) 

    #3#######################################################################

    def extract_keypoints(results):
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
        face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
        return np.concatenate([pose, face, lh, rh])

    #result_test = extract_keypoints(results)
    #np.save('0', result_test)

    #4##########################################################

    # Path for exported data, numpy arrays
    DATA_PATH = os.path.join('MP_Data') 

    # Actions that we try to detect
    #actions = np.array(['hello', 'father', 'iloveyou'])
    actions = np.array(['moja', 'pole', 'baba', 'mbili', 'mimi'])

    # Thirty videos worth of data
    no_sequences = 30

    # Videos are going to be 30 frames in length
    sequence_length = 30

    # Folder start
    start_folder = 30

    for action in actions: 
        for sequence in range(no_sequences):
            try: 
                os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
            except:
                pass

    #6####################################################

    from sklearn.model_selection import train_test_split
    from tensorflow.keras.utils import to_categorical

    label_map = {label:num for num, label in enumerate(actions)}

    sequences, labels = [], []
    for action in actions:
        for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
            window = []
            for frame_num in range(sequence_length):
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
                window.append(res)
            sequences.append(window)
            labels.append(label_map[action])

    X = np.array(sequences)
    y = to_categorical(labels).astype(int)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10)

    #7###################################

    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import LSTM, Dense
    from tensorflow.keras.callbacks import TensorBoard

    log_dir = os.path.join('Logs')
    tb_callback = TensorBoard(log_dir=log_dir)

    model = Sequential()
    model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
    model.add(LSTM(128, return_sequences=True, activation='relu'))
    model.add(LSTM(64, return_sequences=False, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(actions.shape[0], activation='softmax'))

    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

    model.fit(X_train, y_train, epochs=500, callbacks=[tb_callback])

    #8######################################################

    res = model.predict(X_test)

    #9######################################################

    model.save('action.h5')

    #10########################################################

    from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
    yhat = model.predict(X_test)

    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()

    

    return
    
    
    
def display():
    #11######################################################
    import cv2
    import numpy as np
    import os
    from matplotlib import pyplot as plt
    import time
    import mediapipe as mp
    
    mp_holistic = mp.solutions.holistic # Holistic model
    mp_drawing = mp.solutions.drawing_utils # Drawing utilities
    
    def mediapipe_detection(image, model):
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
        image.flags.writeable = False                  # Image is no longer writeable
        results = model.process(image)                 # Make prediction
        image.flags.writeable = True                   # Image is now writeable 
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
        return image, results
    
    def draw_styled_landmarks(image, results):
        # Draw face connections
        #mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
         #                        mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
          #                       mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
           #                      ) 

        # Draw pose connections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 ) 
        # Draw left hand connections
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 ) 
        # Draw right hand connections  
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 ) 
    
    def extract_keypoints(results):
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
        face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
        return np.concatenate([pose, face, lh, rh])
    
     # Path for exported data, numpy arrays
    DATA_PATH = os.path.join('MP_Data') 

    # Actions that we try to detect
    #actions = np.array(['hello', 'father', 'iloveyou'])
    actions = np.array(['moja', 'pole', 'baba', 'mbili', 'mimi'])

    # Thirty videos worth of data
    no_sequences = 30

    # Videos are going to be 30 frames in length
    sequence_length = 30

    # Folder start
    start_folder = 30

    for action in actions: 
        for sequence in range(no_sequences):
            try: 
                os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
            except:
                pass

    
    from sklearn.model_selection import train_test_split
    from tensorflow.keras.utils import to_categorical
    
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import LSTM, Dense
    from tensorflow.keras.callbacks import TensorBoard

    log_dir = os.path.join('Logs')
    tb_callback = TensorBoard(log_dir=log_dir)

    model = Sequential()
    model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
    model.add(LSTM(128, return_sequences=True, activation='relu'))
    model.add(LSTM(64, return_sequences=False, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(actions.shape[0], activation='softmax'))
    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    from scipy import stats

    colors = [(245,117,16), (117,245,16), (16,117,245)]


    # 1. New detection variables
    sequence = []
    sentence = []
    predictions = []
    threshold = 0.5

    cap = cv2.VideoCapture(1)
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():

            # Read feed
            ret, frame = cap.read()

            # Make detections
            image, results = mediapipe_detection(frame, holistic)
            print(results)

            # Draw landmarks
            draw_styled_landmarks(image, results)

            # 2. Prediction logic
            keypoints = extract_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-30:]

            if len(sequence) == 30:
                res = model.predict(np.expand_dims(sequence, axis=0))[0]
                print(actions[np.argmax(res)])
                predictions.append(np.argmax(res))


            #3. Viz logic
                if np.unique(predictions[-10:])[0]==np.argmax(res): 
                    if res[np.argmax(res)] > threshold: 

                        if len(sentence) > 0: 
                            if actions[np.argmax(res)] != sentence[-1]:
                                sentence.append(actions[np.argmax(res)])
                        else:
                            sentence.append(actions[np.argmax(res)])

                if len(sentence) > 1: 
                    sentence = sentence[-1:]

                # Viz probabilities
                #image = prob_viz(res, actions, image, colors)

            cv2.rectangle(image, (0,0), (250, 80), (16, 117, 245), -1) #(seemu ya sentence (START), (UREFU, UPANA), (COLOR), ())
            cv2.putText(image, ' '.join(sentence), (3,50), #(sentence  X, Y)
                           cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 5, cv2.LINE_AA) #(txt size, color, unene wa neno)

            # Show to screen
            cv2.imshow('OpenCV Feed', image)
            matoke = cv2.imshow('OpenCV Feed', image)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()
    
    return
    
    
#signln()

import tkinter as tk
from tkinter import filedialog, Text
import os

root = tk.Tk()
root.title("sign language recognition system")

label = tk.Label(root, text="SIGN LANGUAGE DETECTION FOR THE DEAF AND DUMB", height=2, width=100,)
label.pack()

canvas = tk.Canvas(root, height=300, width=400, bg="#263D42")
canvas.pack()


runapp = tk.Button(root, text="TRAIN", padx=10, pady=5,
                   fg="white", bg="#263D42", command=signln)

display = tk.Button(root, text="DISPLAY", padx=10, pady=5,
                   fg="white", bg="#263D42", command=display)
runapp.pack()
display.pack()

root.mainloop()
# Out:
# Epoch 1/500
# 5/5 [==============================] - 3s 119ms/step - loss: 1.6153 - categorical_accuracy: 0.2000
# Epoch 2/500
# 5/5 [==============================] - 0s 91ms/step - loss: 2.2331 - categorical_accuracy: 0.2222
# Epoch 3/500
# 5/5 [==============================] - 0s 97ms/step - loss: 1.4156 - categorical_accuracy: 0.4444
# Epoch 4/500
# 5/5 [==============================] - 1s 93ms/step - loss: 1.2617 - categorical_accuracy: 0.4593
# Epoch 5/500
# 5/5 [==============================] - 1s 97ms/step - loss: 1.6183 - categorical_accuracy: 0.2222
# Epoch 6/500
# 5/5 [==============================] - 1s 91ms/step - loss: 1.0451 - categorical_accuracy: 0.5407
# Epoch 7/500
# 5/5 [==============================] - 1s 92ms/step - loss: 0.7760 - categorical_accuracy: 0.6000
# Epoch 8/500
# 5/5 [==============================] - 1s 95ms/step - loss: 0.6660 - categorical_accuracy: 0.6889
# Epoch 9/500
# 5/5 [==============================] - 1s 96ms/step - loss: 0.6678 - categorical_accuracy: 0.7481
# Epoch 10/500
# 5/5 [==============================] - 1s 135ms/step - loss: 0.3504 - categorical_accuracy: 0.8519
# Epoch 11/500
# 5/5 [==============================] - 1s 118ms/step - loss: 0.4745 - categorical_accuracy: 0.7185
# Epoch 12/500
# 5/5 [==============================] - 1s 120ms/step - loss: 1.1545 - categorical_accuracy: 0.6889
# Epoch 13/500
# 5/5 [==============================] - 1s 127ms/step - loss: 0.3273 - categorical_accuracy: 0.8148
# Epoch 14/500
# 5/5 [==============================] - 1s 122ms/step - loss: 1.2645 - categorical_accuracy: 0.6370
# Epoch 15/500
# 5/5 [==============================] - 1s 122ms/step - loss: 0.9165 - categorical_accuracy: 0.7259
# Epoch 16/500
# 5/5 [==============================] - 1s 123ms/step - loss: 0.8730 - categorical_accuracy: 0.4370
# Epoch 17/500
# 5/5 [==============================] - 1s 123ms/step - loss: 0.5118 - categorical_accuracy: 0.9926
# Epoch 18/500
# 5/5 [==============================] - 1s 119ms/step - loss: 0.2095 - categorical_accuracy: 0.9481
# Epoch 19/500
# 5/5 [==============================] - 1s 131ms/step - loss: 0.1253 - categorical_accuracy: 0.9556
# Epoch 20/500
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0135 - categorical_accuracy: 1.0000
# Epoch 21/500
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0170 - categorical_accuracy: 1.0000
# Epoch 22/500
# 5/5 [==============================] - 1s 115ms/step - loss: 0.
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mbili

# %%
import tkinter as tk
from tkinter import filedialog, Text
import os

root = tk.Tk()
root.title("sign language recognition system")

label = tk.Label(root, text="SIGN LANGUAGE DETECTION FOR THE DEAF AND DUMB", height=2, width=100,)
label.pack()

canvas = tk.Canvas(root, height=300, width=400, bg="#263D42")
canvas.pack()


runapp = tk.Button(root, text="RUN_APP", padx=10, pady=5,
                   fg="white", bg="#263D42", command=signln)
runapp.pack()

root.mainloop()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import tkinter as tk


def signln():
    # ONE##########################################

        #!pip install tensorflow==2.8.0 tensorflow-gpu==2.8.0 opencv-python mediapipe sklearn matplotlib

    import cv2
    import numpy as np
    import os
    from matplotlib import pyplot as plt
    import time
    import mediapipe as mp

    # 2 #######################################################

    mp_holistic = mp.solutions.holistic  # Holistic model
    mp_drawing = mp.solutions.drawing_utils  # Drawing utilities

    def mediapipe_detection(image, model):
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # COLOR CONVERSION BGR 2 RGB
        image.flags.writeable = False  # Image is no longer writeable
        results = model.process(image)  # Make prediction
        image.flags.writeable = True  # Image is now writeable
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # COLOR COVERSION RGB 2 BGR
        return image, results

    def draw_styled_landmarks(image, results):
        # Draw face connections
        #mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
         #                         mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
          #                       )

        # Draw pose connections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
                                  )
        # Draw left hand connections
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
                                  )
        # Draw right hand connections
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                                  )

        # 3#######################################################################

    def extract_keypoints(results):
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in
                         results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33 * 4)
        face = np.array([[res.x, res.y, res.z] for res in
                         results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
        lh = np.array([[res.x, res.y, res.z] for res in
                       results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(
            21 * 3)
        rh = np.array([[res.x, res.y, res.z] for res in
                       results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(
            21 * 3)
        return np.concatenate([pose, face, lh, rh])

    # result_test = extract_keypoints(results)
    # np.save('0', result_test)

    # 4##########################################################

    # Path for exported data, numpy arrays
    DATA_PATH = os.path.join('MP_Data')

    # Actions that we try to detect
    # actions = np.array(['hello', 'father', 'iloveyou'])
    actions = np.array(['baba', 'mbili', 'pole', 'mimi', 'moja'])

    # Thirty videos worth of data
    no_sequences = 30

    # Videos are going to be 30 frames in length
    sequence_length = 30

    # Folder start
    start_folder = 30

    for action in actions:
        for sequence in range(no_sequences):
            try:
                os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
            except:
                pass

    # 6####################################################

    from sklearn.model_selection import train_test_split
    from tensorflow.keras.utils import to_categorical

    label_map = {label: num for num, label in enumerate(actions)}

    sequences, labels = [], []
    for action in actions:
        for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
            window = []
            for frame_num in range(sequence_length):
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
                window.append(res)
            sequences.append(window)
            labels.append(label_map[action])

    X = np.array(sequences)
    y = to_categorical(labels).astype(int)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

    # 7###################################

    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import LSTM, Dense
    from tensorflow.keras.callbacks import TensorBoard

    log_dir = os.path.join('Logs')
    tb_callback = TensorBoard(log_dir=log_dir)

    model = Sequential()
    model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
    model.add(LSTM(128, return_sequences=True, activation='relu'))
    model.add(LSTM(64, return_sequences=False, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(actions.shape[0], activation='softmax'))

    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

    model.fit(X_train, y_train, epochs=500, callbacks=[tb_callback])

    # 8######################################################

    res = model.predict(X_test)

    # 9######################################################

    model.save('action.h5')

    # 10########################################################

    from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
    yhat = model.predict(X_test)

    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()

    # 11######################################################

    from scipy import stats

    colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245)]

    # 1. New detection variables
    sequence = []
    sentence = []
    predictions = []
    threshold = 0.5

    cap = cv2.VideoCapture(1)
    # Set mediapipe model
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():

            # Read feed
            ret, frame = cap.read()

            # Make detections
            image, results = mediapipe_detection(frame, holistic)
            print(results)

            # Draw landmarks
            draw_styled_landmarks(image, results)

            # 2. Prediction logic
            keypoints = extract_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-30:]

            if len(sequence) == 30:
                res = model.predict(np.expand_dims(sequence, axis=0))[0]
                print(actions[np.argmax(res)])
                predictions.append(np.argmax(res))

                # 3. Viz logic
                if np.unique(predictions[-10:])[0] == np.argmax(res):
                    if res[np.argmax(res)] > threshold:

                        if len(sentence) > 0:
                            if actions[np.argmax(res)] != sentence[-1]:
                                sentence.append(actions[np.argmax(res)])
                        else:
                            sentence.append(actions[np.argmax(res)])

                if len(sentence) > 1:
                    sentence = sentence[-1:]

                # Viz probabilities
                # image = prob_viz(res, actions, image, colors)


            cv2.rectangle(image, (0,0), (250, 80), (16, 117, 245), -1) #(seemu ya sentence (START), (UREFU, UPANA), (COLOR), ())
            cv2.putText(image, ' '.join(sentence), (3,50), #(sentence  X, Y)
                           cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 5, cv2.LINE_AA) #(txt size, color, unene wa neno)

            # Show to screen
            cv2.imshow('OpenCV Feed', image)
            matoke = cv2.imshow('OpenCV Feed', image)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()

        return


def display():
    pass

# signln()

import tkinter as tk
from tkinter import filedialog, Text
import os

root = tk.Tk()
root.title("sign language recognition system")

label = tk.Label(root, text="SIGN LANGUAGE DETECTION FOR THE DEAF AND DUMB", height=2, width=100, )
label.pack()

canvas = tk.Canvas(root, height=300, width=400, bg="#263D42")
canvas.pack()

runapp = tk.Button(root, text="RUN_APP", padx=10, pady=5,
                   fg="white", bg="#263D42", command=signln)

display = tk.Button(root, text="DISPLAY", padx=10, pady=5,
                   fg="white", bg="#263D42", command=display)
runapp.pack()
display.pack()

root.mainloop()
# Out:
# Epoch 1/500
# 5/5 [==============================] - 8s 292ms/step - loss: 1.7891 - categorical_accuracy: 0.1831
# Epoch 2/500
# 5/5 [==============================] - 1s 140ms/step - loss: 2.3830 - categorical_accuracy: 0.1690
# Epoch 3/500
# 5/5 [==============================] - 1s 123ms/step - loss: 1.6014 - categorical_accuracy: 0.2958
# Epoch 4/500
# 5/5 [==============================] - 1s 136ms/step - loss: 1.5454 - categorical_accuracy: 0.2606
# Epoch 5/500
# 5/5 [==============================] - 1s 136ms/step - loss: 1.4661 - categorical_accuracy: 0.3239
# Epoch 6/500
# 5/5 [==============================] - 1s 139ms/step - loss: 1.5796 - categorical_accuracy: 0.1901
# Epoch 7/500
# 5/5 [==============================] - 1s 141ms/step - loss: 1.3318 - categorical_accuracy: 0.3099
# Epoch 8/500
# 5/5 [==============================] - 1s 134ms/step - loss: 0